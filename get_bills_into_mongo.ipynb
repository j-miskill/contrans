# %%
import contrans
import json
import pprint
import pandas as pd
import pymongo

# %%
contrans_obj = contrans.contrans()

# %%
bills_mongo = contrans_obj.connect_to_mongo() # from_scratch will replace all other work and you will have to reupload things

# %%
bioguides = contrans_obj.get_bioguideIDs()

all_congresspeople = list(bioguides['bioguideId'])
contrans_obj.upload_many_members_to_mongo(mongo_bills=bills_mongo, members=all_congresspeople)
# Out:
# uploading bills from N000188 to MongoDB: legislator 1 of 552
# uploading bills from Y000064 to MongoDB: legislator 2 of 552
# uploading bills from W000802 to MongoDB: legislator 3 of 552
# uploading bills from W000800 to MongoDB: legislator 4 of 552
# uploading bills from W000779 to MongoDB: legislator 5 of 552
# uploading bills from W000437 to MongoDB: legislator 6 of 552
# uploading bills from V000137 to MongoDB: legislator 7 of 552
# uploading bills from W000790 to MongoDB: legislator 8 of 552
# uploading bills from T000278 to MongoDB: legislator 9 of 552
# uploading bills from W000817 to MongoDB: legislator 10 of 552
# uploading bills from W000805 to MongoDB: legislator 11 of 552
# uploading bills from V000128 to MongoDB: legislator 12 of 552
# uploading bills from T000476 to MongoDB: legislator 13 of 552
# uploading bills from T000464 to MongoDB: legislator 14 of 552
# uploading bills from T000250 to MongoDB: legislator 15 of 552
# uploading bills from S001198 to MongoDB: legislator 16 of 552
# uploading bills from S000770 to MongoDB: legislator 17 of 552
# uploading bills from S001227 to MongoDB: legislator 18 of 552
# uploading bills from S001217 to MongoDB: legislator 19 of 552
# uploading bills from S001203 to MongoDB: legislator 20 of 552
# uploading bills from S001191 to MongoDB: legislator 21 of 552
# uploading bills from S001184 to MongoDB: legislator 22 of 552
# uploading bills from S001181 to MongoDB: legislator 23 of 552
# uploading bills from S000148 to MongoDB: legislator 24 of 552
# uploading bills from S001194 to MongoDB: legislator 25 of 552
# uploading bills from R000595 to MongoDB: legislator 26 of 552
# uploading bills from S000033 to MongoDB: legislator 27 of 552
# uploading bills from R000615 to MongoDB: legislator 28 of 552
# uploading bills from R000608 to MongoDB: legislator 29 of 552
# uploading bills from R000605 to MongoDB: legislator 30 of 552
# uploading bills from R000584 to MongoDB: legislator 31 of 552
# Process failed for: R000584 on the 31 index.
# 'textVersions'
# uploading bills from R000618 to MongoDB: legislator 31 of 552
# uploading bills from P000145 to MongoDB: legislator 32 of 552
# uploading bills from P000603 to MongoDB: legislator 33 of 552
# uploading bills from P000595 to MongoDB: legislator 34 of 552
# Process failed for: P000595 on the 34 index.
# 'textVersions'
# uploading bills from R000122 to MongoDB: legislator 34 of 552
# uploading bills from O000174 to MongoDB: legislator 35 of 552
# uploading bills from M001169 to MongoDB: legislator 36 of 552
# uploading bills from M001111 to MongoDB: legislator 37 of 552
# uploading bills from M001190 to MongoDB: legislator 38 of 552
# uploading bills from M000934 to MongoDB: legislator 39 of 552
# uploading bills from M001153 to MongoDB: legislator 40 of 552
# uploading bills from M001198 to MongoDB: legislator 41 of 552
# uploading bills from M001183 to MongoDB: legislator 42 of 552
# uploading bills from L000571 to MongoDB: legislator 43 of 552
# Process failed for: L000571 on the 43 index.
# 'textVersions'
# uploading bills from M001176 to MongoDB: legislator 43 of 552
# Process failed for: M001176 on the 43 index.
# 'textVersions'
# uploading bills from M000133 to MongoDB: legislator 43 of 552
# Process failed for: M000133 on the 43 index.
# 'textVersions'
# uploading bills from M000355 to MongoDB: legislator 43 of 552
# uploading bills from K000367 to MongoDB: legislator 44 of 552
# uploading bills from L000577 to MongoDB: legislator 45 of 552
# uploading bills from L000575 to MongoDB: legislator 46 of 552
# Process failed for: L000575 on the 46 index.
# 'textVersions'
# uploading bills from L000570 to MongoDB: legislator 46 of 552
# uploading bills from K000377 to MongoDB: legislator 47 of 552
# uploading bills from K000393 to MongoDB: legislator 48 of 552
# Process failed for: K000393 on the 48 index.
# 'textVersions'
# uploading bills from K000383 to MongoDB: legislator 48 of 552
# uploading bills from H001097 to MongoDB: legislator 49 of 552
# uploading bills from H000273 to MongoDB: legislator 50 of 552
# uploading bills from H001079 to MongoDB: legislator 51 of 552
# uploading bills from K000384 to MongoDB: legislator 52 of 552
# uploading bills from J000293 to MongoDB: legislator 53 of 552
# uploading bills from H001061 to MongoDB: legislator 54 of 552
# uploading bills from H001042 to MongoDB: legislator 55 of 552
# uploading bills from H001089 to MongoDB: legislator 56 of 552
# uploading bills from H001046 to MongoDB: legislator 57 of 552
# uploading bills from H000601 to MongoDB: legislator 58 of 552
# uploading bills from H001076 to MongoDB: legislator 59 of 552
# Process failed for: H001076 on the 59 index.
# 'textVersions'
# uploading bills from G000386 to MongoDB: legislator 59 of 552
# uploading bills from F000479 to MongoDB: legislator 60 of 552
# uploading bills from E000295 to MongoDB: legislator 61 of 552
# Process failed for: E000295 on the 61 index.
# Expecting value: line 1 column 1 (char 0)
# uploading bills from F000463 to MongoDB: legislator 61 of 552
# uploading bills from D000622 to MongoDB: legislator 62 of 552
# uploading bills from G000555 to MongoDB: legislator 63 of 552
# uploading bills from G000359 to MongoDB: legislator 64 of 552
# uploading bills from D000563 to MongoDB: legislator 65 of 552
# uploading bills from C001098 to MongoDB: legislator 66 of 552
# uploading bills from D000618 to MongoDB: legislator 67 of 552
# uploading bills from C001096 to MongoDB: legislator 68 of 552
# uploading bills from C001095 to MongoDB: legislator 69 of 552
# uploading bills from C000880 to MongoDB: legislator 70 of 552
# uploading bills from C001113 to MongoDB: legislator 71 of 552
# uploading bills from C001070 to MongoDB: legislator 72 of 552
# uploading bills from C001088 to MongoDB: legislator 73 of 552
# uploading bills from C001075 to MongoDB: legislator 74 of 552
# uploading bills from C001035 to MongoDB: legislator 75 of 552
# uploading bills from C001056 to MongoDB: legislator 76 of 552
# uploading bills from C001047 to MongoDB: legislator 77 of 552
# uploading bills from C000174 to MongoDB: legislator 78 of 552
# uploading bills from C000141 to MongoDB: legislator 79 of 552
# Process failed for: C000141 on the 79 index.
# 'textVersions'
# uploading bills from B001320 to MongoDB: legislator 79 of 552
# uploading bills from B001305 to MongoDB: legislator 80 of 552
# uploading bills from C000127 to MongoDB: legislator 81 of 552
# uploading bills from B001319 to MongoDB: legislator 82 of 552
# uploading bills from B001310 to MongoDB: legislator 83 of 552
# uploading bills from B001288 to MongoDB: legislator 84 of 552
# uploading bills from B001277 to MongoDB: legislator 85 of 552
# Process failed for: B001277 on the 85 index.
# 'textVersions'
# uploading bills from B001236 to MongoDB: legislator 85 of 552
# uploading bills from B000944 to MongoDB: legislator 86 of 552
# uploading bills from B001261 to MongoDB: legislator 87 of 552
# uploading bills from B001267 to MongoDB: legislator 88 of 552
# uploading bills from B001230 to MongoDB: legislator 89 of 552
# uploading bills from B001243 to MongoDB: legislator 90 of 552
# Process failed for: B001243 on the 90 index.
# 'textVersions'
# uploading bills from L000397 to MongoDB: legislator 90 of 552
# uploading bills from L000604 to MongoDB: legislator 91 of 552
# uploading bills from M001225 to MongoDB: legislator 92 of 552
# uploading bills from M001229 to MongoDB: legislator 93 of 552
# Process failed for: M001229 on the 93 index.
# documents must be a non-empty list
# uploading bills from R000599 to MongoDB: legislator 93 of 552
# uploading bills from D000594 to MongoDB: legislator 94 of 552
# uploading bills from M000639 to MongoDB: legislator 95 of 552
# uploading bills from P000096 to MongoDB: legislator 96 of 552
# uploading bills from J000032 to MongoDB: legislator 97 of 552
# uploading bills from P000604 to MongoDB: legislator 98 of 552
# uploading bills from G000579 to MongoDB: legislator 99 of 552
# uploading bills from K000399 to MongoDB: legislator 100 of 552
# uploading bills from S001159 to MongoDB: legislator 101 of 552
# uploading bills from C001126 to MongoDB: legislator 102 of 552
# uploading bills from R000619 to MongoDB: legislator 103 of 552
# Process failed for: R000619 on the 103 index.
# documents must be a non-empty list
# uploading bills from F000480 to MongoDB: legislator 103 of 552
# uploading bills from K000402 to MongoDB: legislator 104 of 552
# uploading bills from A000380 to MongoDB: legislator 105 of 552
# uploading bills from B001297 to MongoDB: legislator 106 of 552
# uploading bills from C000537 to MongoDB: legislator 107 of 552
# uploading bills from F000476 to MongoDB: legislator 108 of 552
# uploading bills from J000292 to MongoDB: legislator 109 of 552
# uploading bills from M001188 to MongoDB: legislator 110 of 552
# uploading bills from C001132 to MongoDB: legislator 111 of 552
# uploading bills from C001084 to MongoDB: legislator 112 of 552
# uploading bills from V000135 to MongoDB: legislator 113 of 552
# uploading bills from G000600 to MongoDB: legislator 114 of 552
# uploading bills from H001096 to MongoDB: legislator 115 of 552
# uploading bills from B001318 to MongoDB: legislator 116 of 552
# uploading bills from G000595 to MongoDB: legislator 117 of 552
# uploading bills from F000471 to MongoDB: legislator 118 of 552
# uploading bills from T000165 to MongoDB: legislator 119 of 552
# uploading bills from M001205 to MongoDB: legislator 120 of 552
# uploading bills from S001213 to MongoDB: legislator 121 of 552
